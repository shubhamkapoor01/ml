# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamkapoor01/ml/blob/main/Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Churn.csv')

# %%
X = pd.get_dummies(df.drop(['Churn', 'customerID'], axis = 1))
Y = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
X_train.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  gender_Female  gender_Male  \
# 3402              0       4           88.95              1            0
# 3067              0       6           84.40              0            1
# 167               0      72           89.05              0            1
# 6565              0      61          106.20              0            1
# 666               0       2           69.65              1            0
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# 3402           1            0              1               0                0
# 3067           1            0              1               0                0
# 167            0            1              1               0                0
# 6565           0            1              1               0                0
# 666            1            0              1               0                0
#
# ...

# %%
Y_train.head()
# Out:
# 3402    1
# 3067    1
# 167     0
# 6565    0
# 666     1
# Name: Churn, dtype: int64

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Dense(units = 64, activation = 'relu', input_dim = len(X_train.columns)))
model.add(Dense(units = 64, activation = 'relu'))
model.add(Dense(units = 64, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'sgd', metrics = 'accuracy')

# %%
model.fit(X_train, Y_train, epochs = 250, batch_size = 32)
# Out:
# Epoch 1/250
# 177/177 [==============================] - 2s 8ms/step - loss: 0.5043 - accuracy: 0.7540
# Epoch 2/250
# 177/177 [==============================] - 1s 8ms/step - loss: 0.4899 - accuracy: 0.7687
# Epoch 3/250
# 177/177 [==============================] - 1s 8ms/step - loss: 0.4856 - accuracy: 0.7733
# Epoch 4/250
# 177/177 [==============================] - 1s 8ms/step - loss: 0.4778 - accuracy: 0.7780
# Epoch 5/250
# 177/177 [==============================] - 1s 7ms/step - loss: 0.4740 - accuracy: 0.7801
# Epoch 6/250
# 177/177 [==============================] - 1s 7ms/step - loss: 0.4731 - accuracy: 0.7780
# Epoch 7/250
# 177/177 [==============================] - 1s 7ms/step - loss: 0.4672 - accuracy: 0.7831
# Epoch 8/250
# 177/177 [==============================] - 1s 7ms/step - loss: 0.4656 - accuracy: 0.7812
# Epoch 9/250
# 177/177 [==============================] - 1s 7ms/step - loss: 0.4696 - accuracy: 0.7794
# Epoch 10/250
# ...

# %%
Y_hat = model.predict(X_test)
Y_hat = [0 if val < 0.5 else 1 for val in Y_hat]

# %%
accuracy_score(Y_test, Y_hat)
# Out:
# 0.8090844570617459

# %%
model.save('ChurnNN')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
